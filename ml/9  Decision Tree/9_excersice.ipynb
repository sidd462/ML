# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn.model_selection import train_test_split        #! should have used but does not used :  use next time

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("titanic.csv")

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
target=data[['Survived']]
target.head()
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
data=data.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked','Survived'],axis='columns')

# %%
data.head(10)
# Out:
#    Pclass     Sex   Age     Fare
# 0       3    male  22.0   7.2500
# 1       1  female  38.0  71.2833
# 2       3  female  26.0   7.9250
# 3       1  female  35.0  53.1000
# 4       3    male  35.0   8.0500
# 5       3    male   NaN   8.4583
# 6       1    male  54.0  51.8625
# 7       3    male   2.0  21.0750
# 8       3  female  27.0  11.1333
# 9       2  female  14.0  30.0708

# %%
le=LabelEncoder()

# %%
data['Sex_new']=le.fit_transform(data['Sex'])

# %%
data=data.drop(['Sex'],axis="columns")

# %%
data
# Out:
#      Pclass   Age     Fare  Sex_new
# 0         3  22.0   7.2500        1
# 1         1  38.0  71.2833        0
# 2         3  26.0   7.9250        0
# 3         1  35.0  53.1000        0
# 4         3  35.0   8.0500        1
# ..      ...   ...      ...      ...
# 886       2  27.0  13.0000        1
# 887       1  19.0  30.0000        0
# 888       3   NaN  23.4500        0
# 889       1  26.0  30.0000        1
# 890       3  32.0   7.7500        1
#
# [891 rows x 4 columns]

# %%
data=data.fillna(value=data['Age'].median())

# %%
model=tree.DecisionTreeClassifier()

# %%
model.fit(data,target)
# Out:
# DecisionTreeClassifier()

# %%
model.score(data,target)
# Out:
# 0.9775533108866442
